# %% [markdown]
# <a href="https://colab.research.google.com/github/AbelNyc/machine-learning-projects-/blob/main/Pan_tampering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ```
# PAN CARD TEMPERING DETECTION USING COMPUTER VISION:
#
# The purpose of this project is to detect tampering of PAN card using computer vision. This project will help different organization in detecting whether the Id i.e. the PAN card provided to them by their employees or customers is original or fake.
# ```

# %%
from skimage.metrics import structural_similarity 
import imutils 
import cv2
from PIL import Image
import requests

# %%
# !mkdir pan_card_tampering
# !mkdir pan_card_tampering/image

# %%
#open image and display


original = Image.open("/content/drive/MyDrive/original.jpg")
fake = Image.open("/content/drive/MyDrive/tampered.png")

# %%
# the file format of the original and fake file.
print("Original image format: ", original.format)
print("Fake image format: ", fake.format)

# the file size of the original and fake file.
print("Original image format: ", original.size)
print("Fake image format: ", fake.size)
# Out:
# Original image format:  JPEG
# Fake image format:  JPEG
# Original image format:  (250, 160)
# Fake image format:  (250, 160)

# %%
# Resize image 
original = original.resize((240, 160))
print(original.size)

original.save('/content/drive/MyDrive/original.png') #save image


tampered = fake.resize((240,160))
print(tampered.size)
tampered.save("/content/drive/MyDrive/tampered.png")
# Out:
# (240, 160)
# (240, 160)

# %%
original
# Out:
# <PIL.Image.Image image mode=RGB size=240x160 at 0x7F2320398110>

# %%
fake
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=250x160 at 0x7F23202DECD0>

# %%
#load the two input images 
original = cv2.imread("/content/drive/MyDrive/original.png")
fake = cv2.imread("/content/drive/MyDrive/tampered.png")

# %% [markdown]
# USING OPENCV HELPS THE MACHINE PROCESS IMAGES EASILY SINCE GRAYSCALE HAS ONLY ONE CHANNEL WHILE COLORED IMAGES HAVE 3 CHANNELS

# %%
#convert the images to grayscale
ori_gray = cv2.cvtColor(original, cv2.COLOR_BGR2GRAY)
fake_gray = cv2.cvtColor(fake, cv2.COLOR_BGR2GRAY)

# %% [markdown]
# # New Section
